# %% [markdown]
# <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 1 / SPRINT 1 / NOTE 3*
#
# ---
#
# # 📝 Assignment

# %% [markdown]
# # **🌱 기본 과제**

# %% [markdown]
# **Data Description**
#
# - `Poster_Link` : Link of the poster that imdb using
# - `Series_Title` : Name of the movie
# - `Released_Year` : Year at which that movie released
# - `Certificate` : Certificate earned by that movie
# - `Runtime` : Total runtime of the movie
# - `Genre` : Genre of the movie
# - `IMDB_Rating` : Rating of the movie at IMDB site
# - `Overview` : mini story/ summary
# - `Meta_score` : Score earned by the movie (0 ~ 100)
# - `Director` : Name of the Director
# - `Star1` , `Star2` , `Star3` , `Star4` : Name of the Stars
# - `Noofvotes` : Total number of votes
# - `Gross` : Money earned by that movie

# %% [markdown]
# ## **Part 1. EDA**

# %% [markdown]
# ### **1-1. 데이터 불러오기**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# colab에 직접 파일 업로드
url = '/content/movie.csv'

movie = pd.read_csv(url)
movie.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %% [markdown]
# ### **1-2. 데이터 탐색**
#
# - `.info()` 메서드를 통해 데이터에서 아래의 사안을 확인합니다.
#   - 데이터셋의 행과 열 크기를 확인합니다.
#   - 각 column의 데이터 타입이 적절한지 확인합니다.
#   - 결측치 여부를 확인합니다.

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    895 non-null    object
#  4   Runtime        995 non-null    object
#  5   Genre          995 non-null    object
#  6   IMDB_Rating    995 non-null    float64
#  7   Overview       995 non-null    object
#  8   Meta_score     841 non-null    float64
#  9   Director       995 non-null    object
#  10  Star1          995 non-null    object
#  11  Star2          995 non-null    object
#  12  Star3          995 non-null    object
#  13  Star4          995 non-null    object
#  14  No_of_Votes    995 non-null    float64
#  15  Gross          827 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# ##### **Q1. `Released_Year` 안에 숫자가 아닌 잘못된 데이터가 총 몇 개인지 쓰세요.**
#
# - `Released_Year` column의 데이터타입이 object로 나오는 이유는 숫자가 아닌 문자열이 존재하기 때문입니다.
# - [`str.contains()`](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html)를 활용하여 `Released_Year` column 내에 숫자 형태가 아닌 value를 추출해보세요.
#
# > 💡 **Tip)** <br>
# - `.startswith()`
# - `re.findall()`
# - `re.search()`
# - `re.match()` <br>
# 를 활용해볼 수도 있습니다.

# %%
error = movie[movie.Released_Year.str.contains(r'[^0-9]')]
error
# Out:
#                                            Poster_Link  \
# 105  https://m.media-amazon.com/images/M/MV5BODM4Nj...
# 121  https://m.media-amazon.com/images/M/MV5BZmM0NG...
# 951  https://m.media-amazon.com/images/M/MV5BZTI3Yz...
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...
# 975  https://m.media-amazon.com/images/M/MV5BMjE0OD...
#
#                 Series_Title Released_Year Certificate Runtime Genre  \
# 105             Idi i smotri            MA         NaN     NaN   NaN
# 121                    Ikiru             U         NaN     NaN   NaN
# 951          Minority Report         PG-13         NaN     NaN   NaN
# 966                Apollo 13            PG         NaN     NaN   NaN
# 975  When Harry Met Sally...             R         NaN     NaN   NaN
#
#      IMDB_Rating Overview  Meta_score Director Star1 Star2 Star3 Star4  \
# 105          NaN      NaN         NaN      NaN   NaN   NaN   NaN   NaN
# 121          NaN      NaN         NaN      NaN   NaN   NaN   NaN   NaN
# ...

# %%
# findall()을 활용하여 출력해볼 수도 있습니다. 

import re

not_num = []
for year in movie['Released_Year']:
  string = re.compile(r'[\D+]')
  result = string.findall(year)
  if len(result) >= 1:
    not_num.append(year)

not_num
# Out:
# ['MA', 'U', 'PG-13', 'PG', 'R']

# %%
# re.search와 apply를 활용하여 데이터를 추출할 수도 있습니다. 

import re

def has_errors(inputString):
  return bool(re.search('[\D]', inputString))

# %%
error_condition = movie.Released_Year.apply(has_errors)
error_names = movie[error_condition]
error_names
# Out:
#                                            Poster_Link  \
# 105  https://m.media-amazon.com/images/M/MV5BODM4Nj...
# 121  https://m.media-amazon.com/images/M/MV5BZmM0NG...
# 951  https://m.media-amazon.com/images/M/MV5BZTI3Yz...
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...
# 975  https://m.media-amazon.com/images/M/MV5BMjE0OD...
#
#                 Series_Title Released_Year Certificate Runtime Genre  \
# 105             Idi i smotri            MA         NaN     NaN   NaN
# 121                    Ikiru             U         NaN     NaN   NaN
# 951          Minority Report         PG-13         NaN     NaN   NaN
# 966                Apollo 13            PG         NaN     NaN   NaN
# 975  When Harry Met Sally...             R         NaN     NaN   NaN
#
#      IMDB_Rating Overview  Meta_score Director Star1 Star2 Star3 Star4  \
# 105          NaN      NaN         NaN      NaN   NaN   NaN   NaN   NaN
# 121          NaN      NaN         NaN      NaN   NaN   NaN   NaN   NaN
# ...

# %% [markdown]
# ##### **Q2. `Released_Year`에서 숫자가 아닌 잘못된 데이터가 들어있는 행을 삭제한 뒤 전체 행의 개수를 쓰세요.**

# %%
movie = movie.drop(index=error.index).reset_index(drop=True)
movie
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 991  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 992  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 993  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 994  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %% [markdown]
# ### **1-3. 결측치 확인**
#
# - 위의 과정을 모두 거친 데이터 프레임에서, 결측치가 있는 3개의 column에 대해 `.isnull()`을 활용하여 결측치 데이터를 모두 추출하세요.
#   - 추출한 데이터는 데이터프레임 형태로 반환하도록 합니다.
# - 해당 결측치를 어떻게 처리하면 좋을지 생각해봅시다.

# %% [markdown]
# ##### **Q3. 결측치가 있는 행을 모두 추출하여 만든 데이터프레임의 shape을 쓰세요.**

# %%
missing_val = movie[movie['Certificate'].isnull() | movie['Meta_score'].isnull() | movie['Gross'].isnull()]

missing_val
# Out:
#                                            Poster_Link  \
# 18   https://m.media-amazon.com/images/M/MV5BNjViNW...
# 20   https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 30   https://m.media-amazon.com/images/M/MV5BYjBmYT...
# 32   https://m.media-amazon.com/images/M/MV5BZjc4ND...
# 46   https://m.media-amazon.com/images/M/MV5BZmY2Nj...
# ..                                                 ...
# 988  https://m.media-amazon.com/images/M/MV5BYTE4YW...
# 990  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 991  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 993  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 994  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 18                 Hamilton          2020       PG-13  160 min
# 20          Soorarai Pottru          2020           U  153 min
# 30                  Seppuku          1962         NaN  133 min
# ...

# %% [markdown]
# ### **1-4. 아웃라이어 확인**
#
# `Meta_score`의 점수 범위를 살펴보고, 이상치가 존재하는지 판단해봅니다.

# %% [markdown]
# ##### **Q4. `Meta_score`의 범주 안에 포함되지 않는 데이터를 제거한 후, 통계치를 확인하여 전체 `Meta_score`의 평균이 얼마나 변화했는지 반올림하여 소수점 둘째 자리까지 구하세요.**
#
# - `query`를 활용하여 `Meta_score`가 0~100 사이에 있지 않은 데이터를 추출합니다.
# - (해당 데이터를 제거한 후의 평균값) - (해당 데이터를 제거하기 전의 평균값) 의 결과를 반올림하여 소수점 둘째 자리까지 확인합니다.

# %%
movie.Meta_score.sort_values()
# Out:
# 244    -1.0
# 786    28.0
# 940    30.0
# 354    33.0
# 915    36.0
#        ...
# 870     NaN
# 872     NaN
# 897     NaN
# 907     NaN
# 911     NaN
# Name: Meta_score, Length: 995, dtype: float64

# %%
not_included = movie.query("Meta_score < 0 | Meta_score > 100")
not_included
# Out:
#                                            Poster_Link  \
# 244  https://m.media-amazon.com/images/M/MV5BZjJhMT...
#
#                                           Series_Title Released_Year  \
# 244  Shin seiki Evangelion Gekijô-ban: Air/Magokoro...          1997
#
#     Certificate Runtime                     Genre  IMDB_Rating  \
# 244          UA  87 min  Animation, Action, Drama          8.1
#
#                                               Overview  Meta_score  \
# 244  Concurrent theatrical ending of the TV series ...        -1.0
#
#          Director             Star1         Star2               Star3  \
# 244  Hideaki Anno  Kazuya Tsurumaki  Megumi Ogata  Megumi Hayashibara
#
#              Star4  No_of_Votes Gross
# 244  Yûko Miyamura      38847.0   NaN

# %%
movie.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count   995.000000  841.000000  9.950000e+02
# mean      7.949648   77.878716  2.739619e+05
# std       0.275066   12.686121  3.279659e+05
# min       7.600000   -1.000000  2.508800e+04
# 25%       7.700000   70.000000  5.532650e+04
# 50%       7.900000   79.000000  1.383560e+05
# 75%       8.100000   87.000000  3.744775e+05
# max       9.300000  100.000000  2.343110e+06

# %%
final = movie.drop(index=not_included.index).reset_index(drop=True)
final.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count   994.000000  840.000000  9.940000e+02
# mean      7.949497   77.972619  2.741985e+05
# std       0.275163   12.397776  3.280461e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.541675e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.747938e+05
# max       9.300000  100.000000  2.343110e+06

# %%
before = movie.Meta_score.mean()
after = final.Meta_score.mean()

round(after - before, 2)
# Out:
# 0.09

# %% [markdown]
# ### **1-5. 중복값 확인**

# %% [markdown]
# ##### **Q5. 중복되는 데이터의 개수를 쓰세요.**

# %%
final.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # **🥇 도전 과제**

# %% [markdown]
# ##### **`Poster_Link` 피쳐에 형식이 `https://`로 시작하지 않는 데이터를 파악하세요.**

# %%
url_error = final[final.Poster_Link.str.startswith('https://') == False]
url_error
# Out:
#                                            Poster_Link  \
# 3    m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2...
# 10   m.media-amazon.com/images/M/MV5BN2EyZjM3NzUtNW...
# 25   m.media-amazon.com/images/M/MV5BMTUxMzQyNjA5MF...
# 497  m.media-amazon.com/images/M/MV5BMTU3MDc2MjUwMV...
# 747  m.media-amazon.com/images/M/MV5BNGQwZjg5YmYtY2...
#
#                                           Series_Title Released_Year  \
# 3                               The Godfather: Part II          1974
# 10   The Lord of the Rings: The Fellowship of the Ring          2001
# 25                                      The Green Mile          1999
# 497                                         C.R.A.Z.Y.          2005
# 747                                       The Hangover          2009
#
#     Certificate  Runtime                     Genre  IMDB_Rating  \
# 3             A  202 min              Crime, Drama          9.0
# 10            U  178 min  Action, Adventure, Drama          8.8
# ...

# %% [markdown]
# ##### **`Poster_Link`의 모든 데이터가 `https://` 형식이 되도록, 위에서 추출한 오류 데이터에 `https://`를 넣으세요.**

# %%
error_index = url_error.index.to_list()

error_index
# Out:
# [3, 10, 25, 497, 747]

# %%
for i in range(len(final.Poster_Link)):
  if i in error_index:
    final.iloc[i,0] = 'https://' + final.iloc[i,0]

# %%
final[final.Poster_Link.str.startswith('https://') == False]
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []
